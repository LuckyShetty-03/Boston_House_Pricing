# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(C:\Users\user\OneDrive\Desktop\Boston_Housing_Pridiction)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#counting the null values in each column 
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     486.0    3.611874    8.720192    0.00632    0.081900    0.253715
# ZN       486.0   11.211934   23.388876    0.00000    0.000000    0.000000
# INDUS    486.0   11.083992    6.835896    0.46000    5.190000    9.690000
# CHAS     486.0    0.069959    0.255340    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      486.0   68.518519   27.999513    2.90000   45.175000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.440000
# ...

# %%
#sns.heatmap(df.corr(method="pearson"),  cmap="YlGnBu", annot=True)
plt.figure(figsize=(30,12))
cmap = sns.diverging_palette(500,10,as_cmap=True)
sns.heatmap(df.corr(),cmap=cmap,annot=True,center=0,square=True)
# Out:
# <Axes: >

# %%
new_column_names = [
    'Crime_Rate',
    'Large_Lot_Zoning',
    'Non_Retail_Business_Acres',
    'Boundaries_River',
    'Nitrogen_Oxide_Concentration',
    'Avg_Number_of_Rooms',
    'Pre_1940_Units',
    'Distance_to_Employment_Centers',
    'Accessibility_to_Highways',
    'Property_Tax_Rate',
    'Pupil_Teacher_Ratio',
    'Proportion_African_American',
    'Lower_Status_Population',
    'Median_Home_Value'
]

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df['CRIM'].fillna(df['CRIM'].median(), inplace=True)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 100

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df['AGE'].fillna(df['AGE'].median(), inplace=True)
df['ZN'].fillna(df['ZN'].median(), inplace=True)
df['INDUS'].fillna(df['INDUS'].median(), inplace=True)
df['CHAS'].fillna(df['CHAS'].median(), inplace=True)
df['LSTAT'].fillna(df['LSTAT'].median(), inplace=True)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  76.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df["AGE"]=df["AGE"].apply(lambda x:int(x))

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998   45  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18   0.0  0.458  7.147   54  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...  ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593   69  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794   89  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   76  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# ...

# %%
missing_rows = df[df.isnull().any(axis=1)]

# %%
missing_rows
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
particular_clmn = df[df["CHAS"].isnull()]

# %%
particular_clmn
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
df["RM"]=df["RM"].apply(lambda x:int(x))

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538   6   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469   6   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469   7   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458   6   45  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18   0.0  0.458   7   54  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...  ..  ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573   6   69  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93   0.0  0.573   6   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573   6   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573   6   89  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93   0.0  0.573   6   76  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# ...

# %%
df['LSTAT'].fillna(df['LSTAT'].median(), inplace=True)

# %%
df.fillna(0)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538   6   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469   6   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469   7   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458   6   45  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18   0.0  0.458   7   54  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...  ..  ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573   6   69  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93   0.0  0.573   6   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573   6   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573   6   89  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93   0.0  0.573   6   76  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# ...

# %%
#positive level co-relation
correlation = df["RM"].corr(df["MEDV"])
print(f"The correlation between bedrooms and price is: {correlation}")
# Out:
# The correlation between bedrooms and price is: 0.6216919448193294

# %%
#Low level co-relation

correlation = df["DIS"].corr(df["MEDV"])
print(f"The correlation between bedrooms and price is: {correlation}")
# Out:
# The correlation between bedrooms and price is: 0.24992873408590388

# %%
#negative level co-relation

correlation = df["CRIM"].corr(df["MEDV"])
print(f"The correlation between bedrooms and price is: {correlation}")
# Out:
# The correlation between bedrooms and price is: -0.38389515607897146

# %%
#negative level co-relation

correlation = df["NOX"].corr(df["MEDV"])
print(f"The correlation between bedrooms and price is: {correlation}")
# Out:
# The correlation between bedrooms and price is: -0.4273207723732824

# %%
#negative level co-relation
correlation = df["TAX"].corr(df["MEDV"])
print(f"The correlation between bedrooms and price is: {correlation}")
# Out:
# The correlation between bedrooms and price is: -0.46853593356776696

# %%
plt.boxplot(df["MEDV"])
plt.show()

# %%
q1=np.percentile(df["MEDV"],25)
q3=np.percentile(df["MEDV"],75)
iqr=q3-q1

# %%
iqr
# Out:
# 7.975000000000001

# %%
df["MEDV"].median()
# Out:
# 21.2

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig,axs=plt.subplots(nrows=2 ,ncols=7,figsize=(30,12))

for i,ax in zip(df.columns,axs.flat):
    sns.regplot(x=df[i],y=df['MEDV'],color="red",ax=ax)

# %%
df.fillna(0)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538   6   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469   6   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469   7   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458   6   45  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18   0.0  0.458   7   54  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...  ..  ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573   6   69  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93   0.0  0.573   6   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573   6   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573   6   89  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93   0.0  0.573   6   76  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# ...

# %%
x = df.drop(columns = ['MEDV'], axis=1)
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538   6   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469   6   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469   7   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458   6   45  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18   0.0  0.458   7   54  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...  ..  ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573   6   69  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93   0.0  0.573   6   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573   6   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573   6   89  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93   0.0  0.573   6   76  2.5050    1  273     21.0
#
#           B  LSTAT
# 0    396.90   4.98
# 1    396.90   9.14
# ...

# %%
y = df['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# for i in df.columns:
#     df[i] = df[i].fillna(df[i].median(), inplace=True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# df = df.fillna(0)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error 
from sklearn.linear_model import LinearRegression

# %%
# splitting data for 'training' and 'testing'
x_train, x_test, y_train, y_test  =  train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(x_test)

# %%
prediction
# Out:
# array([29.7122317 , 36.68601597, 12.02554559, 27.05373735, 18.40763496,
#        23.69601009, 16.60185799, 14.31136589, 23.02828206, 22.54834153,
#        24.40631559, 19.94794619, -4.52876757, 22.32302313, 19.33795544,
#        23.33635217, 18.67513136,  5.21798727, 38.81790207, 17.68236508,
#        26.40579596, 30.84344468, 11.0026912 , 22.68916054, 19.05491251,
#        16.29309689, 20.86896642, 13.01620872, 22.01422818, 18.99364871,
#        23.71356517, 25.61496066, 24.58125362, 18.53393832, 17.73076254,
#        16.40630548, 31.4155735 , 19.85354681, 26.31181752, 23.73616994,
#        15.33230682, 31.60013029, 43.47246281, 18.03217856, 28.27146038,
#        16.13033991, 14.00559789, 26.34928856, 20.50694488, 30.31802703,
#        22.77456627, 32.38140117, 17.07043269, 25.10922483, 39.38030361,
#        22.38384083, 18.8146857 , 32.12624334, 25.84208506, 12.65359513,
#        21.16398376, 30.89359369, 32.13695865, 17.7474155 , 19.66696277,
# ...

# %%
print("MSE", mean_squared_error(y_test,prediction))
# Out:
# MSE 24.478090723454656

# %%
r2_score(y_test,prediction)
# Out:
# 0.6662099012410087

# %%
#new_data = {"CRIM":0.00632","18.0","2.31","0.0","0.538","6","65","4.0900","1","296","15.3","396.90","4.98"}

# %%
new_data = lr.predict([[0.00632,18.0,2.31,0.0,0.538,6,65,4.0900,1,296,15.3,396.90,4.98]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_data
# Out:
# array([30.31802703])
